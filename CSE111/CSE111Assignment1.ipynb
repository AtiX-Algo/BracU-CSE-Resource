# %% [markdown]
# # CSE111 Lab Assignment 1

# %% [markdown]
# # String
# **Task 1.** From a given string, print the string in all uppercase if the number of uppercase
# letters is more than lowercase letters. Otherwise, if lowercase is greater or equal
# to uppercase letters, print all lowercase.
#
# **<font color='red'>The inputs will contain letters (A-Z, a-z)
# only.</font>**
#
# **Sample Input**\
# HOusE\
# ApplE\
# BaNaNa
#
# **Sample Output**\
# HOUSE\
# apple\
# banana

# %%
cap=0
sma=0
String=input("Give a String String: ")
for char in ((String)):
    if char>="A" and char<="Z":
        cap+=1
    elif char>="a" and char<="z":
        sma+=1
if sma>=cap:
    print(String.lower())
else:
    print(String.upper())
# Out:
# Give a String String: ApplE
# apple

# %%
######1######
cap=0
sma=0
String=input("Give a String String: ")
for i in range(len(String)):
    if "A"<=String[i]<="Z":
        cap+=1
    elif "a"<=String[i]<="z":
        sma+=1
if sma>=cap:
    print(String.lower())
else:
    print(String.upper())
# Out:
# Give a String String: HOusE
# HOUSE

# %% [markdown]
#  **2.** Given a string, print whether it is a number, word or mixed with digit andletters.
# If all the characters are numeric values, print NUMBER. If they are all letters,
# print WORD. If it is mixed, print MIXED.
#
# **Sample Input**\
# 213213\
# jhg231j213\
# Hello
#
# **Sample Output**\
# NUMBER\
# MIXED\
# WORD

# %%
num=0
wrd=0
String=input()
for char in String:
    if char>="A" and char<="Z" or char>="a" and char<="z":
        wrd+=1
    elif char<="9" and char>="0":
        num+=1
if num>0 and wrd>0:  #string.isalnum(
    print("MIXED")
elif num>0:         #string.isdigit
    print("NUMBER")
elif wrd>0:         #string.isalpha()
    print("WORD")
# Out:
# 273gakcxcn
# MIXED

# %%
#########2############
num=0
wrd=0
string=input()
for char in range(len(string)):
    if "A"<=string[char]<="Z" or "a"<=string[char]<="z":
        wrd+=1
    elif "0"<=string[char]<="9":
        num+=1
if num>0 and wrd>0:
    print("MIXED")
elif num>0:
    print("NUMBER")
elif wrd>0:
    print("WORD")
# Out:
# gdsygds
# WORD

# %% [markdown]
# **3.** In a given string, there will be two uppercase letters in between some lowercase
# letters. Print the substring from the first uppercase letter to the last uppercase
# letter excluding them. If there are no letters in between them, print the word
# BLANK. It is guaranteed that there will be only two uppercase letters in the
# string.
#
# **Sample Input**\
# baNgladEsh\
# coDIng
#
# **Sample Output**\
# glad\
# BLANK

# %%
given_string = input()
upper_count = 0
middle_word = ''

for char in given_string:

  if (upper_count > 0 and upper_count < 2):
    if (char>='a' and char <='z'):
      middle_word+=char
  if (char>='A' and char <='Z'):
    upper_count+=1
  if (upper_count==2):
    break

if len(middle_word):
  print(middle_word)
else:
  print("BLANK")
# Out:
# baNgladEsh
# glad

# %%
ui = input('Enter a string: ')
x = 0
ans = ""
for char in ui:
    if x == 1:
        ans += char
    if char.isupper():
        x += 1

if len(ans) == 0:
    print('BLANK')
else:
    print(ans[:-1])
# Out:
# Enter a string: baNgladEsh
# glad

# %%
###########3$$$$$$$$$$$$$$
string = input()
count = 0
middle_letter = []

for i in range(len(string)):
    if count ==2:
        break
    if string[i].isupper():
        middle_letter.append(i)
        count+=1
if abs(middle_letter[0]-middle_letter[1])!=1:
    print(string[middle_letter[0]+1:middle_letter[1]])
else:
    print("BLANK")
# Out:
# baNgladEsh
# glad

# %%
string = input()
count = 0
middle_letter = []

for i in range(len(string)):
    if count ==2:
        break
    if  "A"<=string[i]<="Z":
        middle_letter.append(i)
        count+=1
if abs(middle_letter[0]-middle_letter[1])!=1:
    print(string[middle_letter[0]+1:middle_letter[1]])
else:
    print("BLANK")
# Out:
# baNgladEsh
# glad

# %%
string = input()
count = 0
middle_letter = []

for i in range(len(string)):
    if string[i].isupper():
        if "A" <= string[i] <= "Z":
            middle_letter.append(i)
            count += 1
        if count == 2:
            break

if count == 2:
    print(string[middle_letter[0]+1:middle_letter[1]])
else:
    print("BLANK")
# Out:
# baNgladEsh
# glad

# %% [markdown]
# **4.** Create a string from two given strings by concatenating common characters of
# the given strings.
#
# **Sample Input**\
# harry, hermione \
# dean, tom
#
# **Sample Output**\
# hrrhr\
# Nothing in common

# %%
#############4################
first_string =  input("Please enter 1st String: ")
second_string =  input("Please enter 2nd String: ")
new_string = ''

for char in first_string:
  if char in second_string:
    new_string += char



for char in second_string:
  if char in first_string:
    new_string+= char

if (len(new_string)):
  print(new_string)
else:
  print("Nothing in common.")
# Out:
# Please enter 1st String: harry
# Please enter 2nd String: hermione
# hrrhr

# %% [markdown]
# **5.** Again, you have lost your USIS password!! You went to the registrar office
# and requested for a new password. This time, you need to follow some rules to
# set your password. Otherwise, they won't change it. The rules are
#
#    At least one lowercase letter\
#    At least one uppercase letter \
#    At least one digit (0-9)\
#    At least one special character (_ , $ , #, @)
#
#
# Your task is to find whether a given password follows all those rules. If it breaks
# any rule, you have to print Lowercase Missing, Uppercase Missing, Digit Missing
# or Special Missing respective to the missing case. For more than one rule break,
# print all the rules that were broken (order doesn't matter). If the password is ok,
# print OK.
#
# **Sample Input**\
# ohMyBR@CU\
# ohmybracu\
# OhMyBR@CU20
#
# **Sample Output**\
# Digit missing\
# Uppercase character missing, Digit missing, Special character missing\
# OK

# %%
pas=input("Take a string: ")
lcase=""
ucase=""
digit=""
special=""

x=['_','$','#','@']

for i in pas:
    if 97<=ord(i)<=122:
        lcase+=i
    elif 65<=ord(i)<=90:
        ucase+=i
    elif 48<=ord(i)<=57:
        digit+=i
    elif i in x:
        special+=i
fnl=" "
if len(lcase)==0:
    fnl +="Lowercase is missing,"
if len(ucase)==0:
    fnl +="Uppercase is missing,"
if len(digit)==0:
    fnl +="Digit is missing,"
if len(special)==0:
    fnl +="Special character is missing"

elif len(lcase)>=1 and len(ucase)>=1 and len(digit)>=1 and len(special)>=1:
    print("OK")
else:
    print(fnl[:-1])
# Out:
# Take a string: ohmybracu

# %%
pas=input("Take a string: ")
lcase=""
ucase=""
digit=""
special=""

x=['_','$','#','@']

for i in pas:
    if 97<=ord(i)<=122:
        lcase+=i
    elif 65<=ord(i)<=90:
        ucase+=i
    elif 48<=ord(i)<=57:
        digit+=i
    elif i in x:
        special+=i
fnl=" "
if len(lcase)==0:
    fnl +="Lowercase is missing,"
    #print("Lowercase is missing,",end="")
if len(ucase)==0:
    fnl +="Uppercase is missing,"
    #print("Uppercase is missing,",end="")
if len(digit)==0:
    fnl +="Digit is missing,"
    #print("Digit is missing,",end="")
if len(special)==0:
    fnl +="Special character is missing,"
    #print("Digit is missing,",end="")

if len(lcase)>=1 and len(ucase)>=1 and len(digit)>=1 and len(special)>=1:
    print("OK")
else:
    print(fnl[:-1])
# Out:
# Take a string: ohMyBR@CU
#  Digit is missing

# %%
pas = input("Take a string: ")
lcase = 0
ucase = 0
digit = 0
special = 0

x = ['_','$','#','@']

for char in pas:
    if "A" <= char <= "Z":
        ucase += 1
    elif "a" <= char <= "z":
        lcase += 1
    elif "0" <= char <= "9":
        digit += 1
    elif char in x:
        special += 1

fnl = ""

if lcase == 0:
    fnl += "Lowercase is missing,"
if ucase == 0:
    fnl += "Uppercase is missing,"
if digit == 0:
    fnl += "Digit is missing,"
if special == 0:
    fnl += "Special character is missing,"

if lcase >= 1 and ucase >= 1 and digit >= 1 and special >= 1:
    print("OK")
else:
    print(fnl[:-1])
# Out:
# Take a string: ohMyBR@CU
# Digit is missing

# %% [markdown]
# ### List
# **1.** Write a python program which prints the frequency of the numbers that were given
# as input by the user. Stop taking input when you find the string “STOP”. Do not
# print the frequency of numbers that were not given as input.
#
# **Sample Input**\
# 10\
# 20\
# 20\
# 30\
# 10\
# 50\
# 90\
# STOP
#
# **Sample Output**\
# 10 - 2 times\
# 20 - 2 times\
# 30 - 1 times\
# 50 - 1 times\
# 90 - 1 times

# %%
num_list = []
while True:
  user_input = input()
  if user_input == "STOP":
    break
  else:
    num_list.append(user_input)

temp_list =[]
for item in num_list:
  if item not in temp_list:
    temp_list.append(item) #to get the unique numbers

for item in temp_list:
  count = num_list.count(item)
  print("{} - {} times".format(item,count))
# Out:
# 10
# 20
# STOP
# 10 - 1 times
# 20 - 1 times

# %%
######################
list1=[]
list2=[]
num=input()

while num!='STOP':
    list1.append(num)
    num=input()
list2.append(list1[0])

for p in range(1,len(list1),1):
    if list1[p] not in list2:
        list2.append(list1[p])

for p in list2:
    x=list1.count(p)
    print(p,'-',x,'times')
# Out:
# 10
# 30
# 50
# 40
# 10
# 40
# STOP
# 10 - 2 times
# 30 - 1 times
# 50 - 1 times
# 40 - 2 times

# %%
#list
#task1
a=[]
b=[]
while True:
  n=input()
  if n=='STOP':
    break
  else:
    n=int(n)
    a.append(n)
for i in a:
  if i not in b:
    b.append(i)
for j in b:
  c=a.count(j)#do not use count function

  print(j,'-',c,'times')
# Out:
# 10
# 10
# 20
# STOP
# 10 - 2 times
# 20 - 1 times

# %% [markdown]
# **2.** Write a python program that calculates the sum of N given lists and prints the highest
# sum and its respective list. Input starts with N and followed by N lists.
#
# **Sample Input**\
# 4\
# 1 2 3\
# 4 5 6\
# 10 11 12\
# 7 8 9
#
# **Sample Input**\
# 4\
# 1 2 3\
# 4 5 6\
# 10 11 12\
# 7 8 9

# %%
highest_sum = 0
list_of_highest_sum = []

list_count = int(input())

for i in range(list_count):
  initial_list = input().split()
  initial_highest_sum = 0

  for item in initial_list:
    initial_highest_sum +=int(item)

  if initial_highest_sum > highest_sum:
    highest_sum = initial_highest_sum
    list_of_highest_sum = initial_list.copy()

print("{}\n{}".format(highest_sum,list_of_highest_sum))
# Out:
# 4
# 1 2 3
# 4 5 6
# 10 11 12
# 7 8 9
# output 33
# ['10', '11', '12']

# %% [markdown]
# ## **3.** Let there are N numbers in a list and that list is said to be a UB Jumper if the
# absolute values of the difference between the successive elements take on all the
# values 1 through N − 1. For example, 2 1 4 6 10 is a UB Jumper because the absolute
# differences between them are 1 3 2 4 which is all numbers from 1 to (5 - 1) or 4.
# **Write a python program that takes a number sequence as input and prints
# whether it is a UB Jumper or Not UB Jumper. Input will stop after getting
# “STOP” as input.** (Number order or absolute difference order doesn’t follow any
# sequence.)
#
# **Sample Input**\
# 1 4 2 \
# 2 1 4 6 10\
# 1 4 2 -1 6\
# STOP
#
# **Sample Output**\
# UB Jumper\
# UB Jumper\
# Not UB Jumper

# %%
while True:
    seq = input().strip().split()

    if seq[0] == "STOP":
        break

    seq = list(map(int, seq))
    d = [abs(seq[i] - seq[i + 1]) for i in range(len(seq) - 1)]

    if sorted(d) == list(range(1, len(seq))):
        print("UB Jumper")
    else:
        print("Not UB Jumper")
# Out:
# 1 4 2
# Not UB Jumper
# STOP

# %% [markdown]
# **4.** BRACU has n students who are regular competitive programmers. According
# to the ACM ICPC rules, each person can participate in the regional championship
# at most 5 times.
#
# The head of the BRACU ACM Chapter is recently gathering teams to participate
# in this championship. Each team must consist of exactly three people, at that, any
# person cannot be a member of two or more teams. What maximum number of teams
# can the head make if he wants each team to participate in the world championship
# with the same members at least k times?
#
# The first line of input contains two integers, n and k. The next line contains n
# integers: y1,y2, ...,yn (0≤ yi≤ 5), where yi shows the number of times the i-thperson
# participated in the ACM ICPC Regional.
#
# **Write a python program that prints how many teams can be formed according to
# the above problem statement.**
#
# **Sample Input 1**\
# 5 2\
# 0 4 5 1 0
#
# **Sample Input 2**\
# 6 4\
# 0 1 2 3 4 5
#
# **Sample Input 3**\
# 6 5\
# 0 0 0 0 0 0
#
#
# **Sample Output 1**\
# 1\
# **Sample Output 2**\
# 0\
# **Sample Output 3**\
# 2

# %%
# Input
n, k = map(int, input().split())
participation = list(map(int, input().split()))

# Calculate the maximum number of teams
teams_count = 0

for i in range(0, n, 3):
    team_participation = participation[i:i+3]
    team_participation_sum = sum(team_participation)
    if team_participation_sum >= 3 * (5 - k):
        teams_count += 1

# Output
print("Output:",teams_count)
# Out:
# 5 2
# 0 4 5 1 0
# Output: 1

# %% [markdown]
# # Dictionary & Tuple
# **1.** Write a Python program to combine two dictionaries into one by adding values for
# common keys. Input contains two comma separated dictionaries. Print the new
# dictionary and create a tuple which contains unique values in sorted order.
#
# **Sample Input**\
# a: 100, b: 100, c: 200, d: 300\
# a: 300, b: 200, d: 400, e: 200
#
# **Sample Output**\
# {'a': 400, 'b': 300, 'c': 200,'d': 700, 'e': 200}\
# Values: (200, 300, 400, 700)

# %%
input_str1 = "a: 100, b: 100, c: 200, d: 300"
input_str2 = "a: 300, b: 200, d: 400, e: 200"

dict1 = {k.strip(): int(v.strip()) for k, v in (item.split(':') for item in input_str1.split(','))}
dict2 = {k.strip(): int(v.strip()) for k, v in (item.split(':') for item in input_str2.split(','))}


combined_dict = {}
unique_values = set()

for key in dict1.keys() | dict2.keys():
    combined_dict[key] = dict1.get(key, 0) + dict2.get(key, 0)
    unique_values.add(combined_dict[key])

print("Combined Dictionary:", combined_dict)

print("Values:", tuple(sorted(unique_values)))
# Out:
# Combined Dictionary: {'d': 700, 'b': 300, 'c': 200, 'a': 400, 'e': 200}
# Values: (200, 300, 400, 700)

# %% [markdown]
# **2.** Write a python program which prints the frequency of the numbers that were
# given as input by the user. Stop taking input when you find the string “STOP”.Do
# not print the frequency of numbers that were not given as input. Use a dictionary
# to solve the problem
#
# **Sample Input**\
# 10\
# 20\
# 20\
# 30\
# 10\
# 50\
# 90\
# STOP

# %%
d = {}

while True:
    inp = input("Enter a number (or 'STOP' to end): ")

    if inp.upper() == "STOP":
        break

    try:
        n = int(inp)
        d[n] = d.get(n, 0) + 1
    except ValueError:
        print("Invalid input. Please enter a valid number.")

for n in d:
    frequency = d[n]
    print("Number {}: {} times".format(n, frequency))
# Out:
# Enter a number (or 'STOP' to end): 10
# Enter a number (or 'STOP' to end): 20
# Enter a number (or 'STOP' to end): 20
# Enter a number (or 'STOP' to end): STOP
# Number 10: 1 times
# Number 20: 2 times
